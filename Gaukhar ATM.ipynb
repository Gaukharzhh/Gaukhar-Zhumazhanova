# %% [markdown]
# Zhumazhanova Gaukhar

# %%
import re

# %%
print('Welcome to the ZZZ ATM')
restart=('y','yes','Y','Yes')
chances = 3
balance = 9999
while chances >= 0:
    password = int(input('Please Enter You password: '))
    if ('Password>999 or Password<9999'):
        print('Your password is Correct\n')
        while restart not in ('n','NO','no','N','Not','not'):
            print('Press 1 For Current Balance \n')
            print('Press 2 To Withdrawl \n')
            print('Press 3 To Deposit \n')
            print('Press 4 To Exit \n')
            option = int(input('Choose your option'))
            if option == 1:
                print('Your Current Balance is $',balance,'\n')
                restart = input('Would You you like to return to the menu? ')
                if restart in ('n','NO','no','N','Not','not'):
                    print('Thank You')
                    break
            elif option == 2:
                option2 = ('y','yes','Y','Yes')
                withdrawl = float(input('Amount of withdraw \n$10/$30/$50/$70/$90/$100: '))
                if withdrawl in [10, 30, 50, 70, 90, 100]:
                    balance = balance - withdrawl
                    print ('\nYour Updated Balance is now $',balance)
                    restart = input('Would You you like to return to the menu? ')
                    if restart in ('n','NO','no','N','Not','not'):
                        print('Thank You')
                        break
                elif withdrawl != [10, 30, 50, 70, 90, 100]:
                    print('Error, Please Re-enter\n')
                    restart = ('y','yes','Y','Yes')
                elif withdrawl == 1:
                    withdrawl = float(input('Enter your Withdrawal amount:'))    

            elif option == 3:
                Deposit = float(input('Amount of deposit '))
                balance = balance + Deposit
                print ('\nYour Updated Balance is now $',balance)
                restart = input('Would You you like to return to the menu? ')
                if restart in ('n','NO','no','N','Not','not'):
                    print('Thank You')
                    break
            elif option == 4:
                print('Take a card first, please...\n')
                print('Thank you for choosing our Bank')
                break
            else:
                print('Please Enter a correct number. \n')
                restart = ('y')
    elif password != ('Password>999 or Password<9999'):
        print('Incorrect Password')
        chances = chances - 1
        if chances == 0:
            print('\nInvalid! Try later!!!')
            break
# Out:
# Welcome to the ZZZ ATM
# Please Enter You password: 6666
# Your password is Correct
#
# Press 1 For Current Balance
#
# Press 2 To Withdrawl
#
# Press 3 To Deposit
#
# Press 4 To Exit
#
# Choose your option1
# Your Current Balance is $ 9999
#
# Would You you like to return to the menu? y
# Press 1 For Current Balance
#
# Press 2 To Withdrawl
#
# Press 3 To Deposit
#
# Press 4 To Exit
#
# Choose your option2
# Amount of withdraw
# $10/$30/$50/$70/$90/$100: 100
#
# Your Updated Balance is now $ 9899.0
# Would You you like to return to the menu? yes
# Press 1 For Current Balance
#
# Press 2 To Withdrawl
#
# Press 3 To Deposit
#
# Press 4 To Exit
#
# Choose your option3
# Amount of deposit 6790
#
# Your Updated Balance is now $ 16689.0
# Would You you like to return to the menu? y
# Press 1 For Current Balance
#
# Press 2 To Withdrawl
#
# Press 3 To Deposit
#
# Press 4 To Exit
#
# Choose your option4
# Take a card first, please...
#
# Thank you for choosing our Bank
